# %%
# Single Line Comment

# %%
""" this is multiline comment """
# Out:
# ' this is multiline comment '

# %%
""" this is 
multiline 
comment """
# Out:
# ' this is \nmultiline \ncomment '

# %%
import math  ## library has mathematical functions.

# %%
dir(math)  ## Gives mathematical function within this library 
## dir gives the list of funcction available in math librarty
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
print (dir(math))  ## also works
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %%
# if we want to know the functionality of function
# help gives documentation of particular funct

# %%
print (help(math.sqrt))
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.
#
# None

# %%
print (math.sqrt(20))
# Out:
# 4.47213595499958

# %%
help(math.pow)  ## power function in math library
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
math.pow(2,8)
# Out:
# 256.0

# %%
import math as mt  ## Referring math library as new name mt

# %%
mt.sqrt(20)
# Out:
# 4.47213595499958

# %%
## Various ways of importing

# %%
import pandas as pd
import numpy 
import matplotlib

# %%
# Input 
# Takes input from user

# %%
city = input("Enter the city name:")
# Out:
# Enter the city name:Dhanbad

# %%
print(city)
# Out:
# Dhanbad

# %%
type (city)  ## string type
# Out:
# str

# %%
## Input method will always read data in string type.

# %%
str1 = "Forsk Coding School"

# %%
type(str1)
# Out:
# str

# %% [markdown]
# ##  Ways for defining/declaring String

# %%
str1 = 'Forsk Coding School'  ## Double QUOTES AND SINGLE Quotes

# %%
type(str1)
# Out:
# str

# %%
str1 = """Forsk Coding School""" ## Triple quotes

# %%
type(str1)
# Out:
# str

# %%
str1 = "F"

# %%
type(str1)   ## In c it would have been character but in python it is string
# Out:
# str

# %%
## str1 every time we declare , it is update with new value

# %%
str1 = 'F'

# %%
type(str1)
# Out:
# str

# %%
## Length

# %%
str1 = "Forsk Coding School"   ## Include spaces

# %%
print(len(str1))
# Out:
# 19

# %% [markdown]
# #### Indexing / Slicing

# %%
print(str1[0])  ### 0 indicates index and refer first letter or str1[0]
# Out:
# F

# %%
## Range

# %%
print(str1[0:10])  ### From index 0 to index 9 not index 10
# Out:
# Forsk Codi

# %% [markdown]
# #### reverse indexing

# %%
## prev we used forward indexing

# %%
str1[-1]  ## Print the last letter from string
# Out:
# 'l'

# %%
str1[-2]  ## second last charater
# Out:
# 'o'

# %%
str1 = "Corona Pandmeic"

# %%
str1.upper()   ## upper case
# Out:
# 'CORONA PANDMEIC'

# %%
## Note only output has changed  but original str1 remains same
str1
# Out:
# 'Corona Pandmeic'

# %%
str2 = str1.upper()

# %%
str2
# Out:
# 'CORONA PANDMEIC'

# %%
str1  ## will give string name as it was assigned initially
# Out:
# 'Corona Pandmeic'

# %%
print(str1)  ## will print output
# Out:
# Corona Pandmeic

# %%
str1 = "JAIPUR"

# %%
str1.lower()
# Out:
# 'jaipur'

# %%
str1  ## str1 is not changed
# Out:
# 'JAIPUR'

# %%
str1 = "JAIPUR"

# %%
str1[0] = 'j'  ## assignment of new letter gives error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-46cf7ea6bbcb> in <module>
# ----> 1 str1[0] = 'j'  ## assignment of new letter gives error
#
# TypeError: 'str' object does not support item assignment

# %%
####TypeError: 'str' object does not support item assignment
## Strings are read only and cannot be changed
## immutable in python means cannot be changed
## Strings are immutable

# %%
## Other datatypes

# %%
age  = 32  ## we dont have to initailize

# %%
type (age)
# Out:
# int

# %%
marks = 41.2

# %%
type (marks)  ## No concept of double in python , either float or int
# Out:
# float

# %%
status = True  ### Boolean value assignment. T capital case sensitive

# %%
type (status)
# Out:
# bool

# %%
a = None   ## None is a value and NoneType is datatype ## works when we dont know values for variable in project 
# We can initally assign none.  
## Type of null value

# %%
type (a)
# Out:
# NoneType

# %%
marks = input ("Enter the marks: ")  ## Input the marks from user
# Out:
# Enter the marks: 40

# %%
marks  ## this type is str, we can typecast to integer
# Out:
# '40'

# %% [markdown]
# ### Converting datatypes

# %%
marks = int(marks) ##typecasted to integer

# %%
type (marks)
# Out:
# int

# %%
## Input the marks from user if he is pass or fail based on marks

# %%
if(marks >= 33):  ## Conditional statement
    print("Pass...congrats")
# Out:
# Pass...congrats

# %%
marks = input ("Enter the marks: ")     ## Now if we check if marks less than 33
# Out:
# Enter the marks: 20

# %%
type (marks)
# Out:
# str

# %%
marks = int(marks) ##typecasted to integer

# %%
if(marks >= 33):  ## Conditional statement fails ## Not working since condition is false
    print("Pass...congrats")

# %%
marks >= 33
# Out:
# False

# %%
if(marks >= 33):  ## Conditionl statement  ##We have now use if else statement
    print("Pass...congrats")
else:
    print("Fail...good luck next time")
# Out:
# Fail...good luck next time

# %%
##Below is the the final statements to check if student is pass or fail after entering marks from user

# %%
marks = input ("Enter the marks: ")
# Out:
# Enter the marks: 40

# %%
type (marks)
# Out:
# str

# %%
marks = int(marks) ##typecasted to integer

# %%
if(marks >= 33):  ## Conditionl statement  ## We have now use if else statement
    print("Pass...congrats")
else:
    print("Fail...good luck next time")
# Out:
# Pass...congrats

# %%
## Now I want to check this for 50 students
## but the process will be tedious since evrytime we need to enter marks
## Loop is the solution

# %% [markdown]
# ### We will use While loop

# %%
#while(True):  ## while loop runs for infinte time as this condition is True or 1 can be written or non zero number

# %%
#while(True):   ## Will run for infinite time printing in while loop
#    print('in while loop')

# %%
## Now we want to run with while loop marks staement

# %%
#while(True):   
#    print('in while loop')

# %%
marks = input ("Enter the marks: ")
# Out:
# Enter the marks: 33

# %%
type (marks)
# Out:
# str

# %%
marks = int(marks) ##typecasted to integer

# %%
if(marks >= 33):  ## Conditionl statement  ##We have now use if else statement
    print("Pass...congrats")
else:
    print("Fail...good luck next time")
# Out:
# Pass...congrats

# %%
while(True):   ## Gives error if gives enter otherwise keeps running
    marks = input ("Enter the marks: ") 
    type (marks)
    marks = int(marks) 
    if(marks >= 33):  
        print("Pass...congrats")
    else:
        print("Fail...good luck next time")
# Out:
# in while loop
# Enter the marks: 3
# Fail...good luck next time
# in while loop
# Enter the marks: 67
# Pass...congrats
# in while loop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-26683e25ebf9> in <module>
#       1 while(True):
#       2     print('in while loop')
# ----> 3     marks = input ("Enter the marks: ")
#       4     type (marks)
#       5     marks = int(marks)
#
# ~\Anan\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\Anan\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
## Now we want to comeout of this loop
##  We have to use break statement

# %%
while(True):   
    print('in while loop')
    marks = input ("Enter the marks: ") 
    
    if not marks:
        print("exiting from the loop")  ##  We just pressed enter
        break  ## terminate loop execution check below line for concept
    
    type (marks)
    marks = int(marks) 
    if(marks >= 33):  
        print("Pass...congrats")
    else:
        print("Fail...good luck next time")
# Out:
# in while loop
# Enter the marks: 3
# Fail...good luck next time
# in while loop
# Enter the marks:
# exiting from the loop

# %%
##Enter the marks:  We just pressed enter
## exiting from the loop

# %%
## check below concept for  breaking while loop above

# %%
marks = '40'

# %%
not marks  ## It tells mark string is not empty
# Out:
# False

# %%
marks = '60'

# %%
not marks
# Out:
# False

# %%
marks = ""

# %%
not marks
# Out:
# True

# %%
#Will give error if we use if not marks at bottom

# %%
while(True):   
    print('in while loop')
    marks = input ("Enter the marks: ") 
    type (marks)
    marks = int(marks) 
    if(marks >= 33):  
        print("Pass...congrats")
    else:
        print("Fail...good luck next time")
        
    if not marks:
        print("exiting from the loop")  ##  We just pressed enter
        break  ## terminate loop execution check below line for concept
# Out:
# in while loop
# Enter the marks: 3
# Fail...good luck next time
# in while loop
# Enter the marks: 3
# Fail...good luck next time
# in while loop
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-4197f90e4fd7> in <module>
#       1 while(True):
#       2     print('in while loop')
# ----> 3     marks = input ("Enter the marks: ")
#       4     type (marks)
#       5     marks = int(marks)
#
# ~\Anan\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\Anan\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
## till now are working on pythion in built datastructure

# %% [markdown]
# # List can take integer, float , string , boolean all values

# %%
list1 = [1,2,3,4,5,6]  ## We can take integer, float , string , boolean all values

# %%
type(list1)   ## Called array in C
# Out:
# list

# %%
list1[0]
# Out:
# 1

# %%
list1[-1] ## print last item
# Out:
# 6

# %%
list1  = [1, 2.3, True]

# %%
type(list1)
# Out:
# list

# %%
list1 = [1,2,3,4,5,6]

# %%
# Printing one item at time
## We will use for loop

# %%
for item in list1:  ## not working as index, working as iterator, in first iteration item is 1 , then second 2 and so on
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for x in list1: ## We can take any name in place of x.
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
list1[0] = 10 ## this was not allowed in string

# %%
list1
# Out:
# [10, 2, 3, 4, 5, 6]

# %% [markdown]
# ### List are mutable and can be changed.
# ###### this was not allowed in string

# %%
list1
# Out:
# [1, 10, 2, 10]

# %%
## Addding new item to list

# %%
list1.append(100)  ## 100 added to last

# %%
list1
# Out:
# [10, 2, 3, 4, 5, 6, 100]

# %%
## append add item to last

# %%
list1.insert(1,101)

# %%
list1
# Out:
# [10, 101, 2, 3, 4, 5, 6, 100]

# %%
## insert add item based on index position. the value will shift right

# %%
## How many functions in list by writing dir.

# %%
dir(list1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list1
# Out:
# [10, 101, 2, 3, 4, 5, 6, 100]

# %%
list1.remove(10)

# %%
list1
# Out:
# [101, 2, 3, 4, 5, 6, 100]

# %%
list1.remove(1000)  ## if item not in list will throw error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-35bbc433a90a> in <module>
# ----> 1 list1.remove(1000)  ## if item not in list will throw error
#
# ValueError: list.remove(x): x not in list

# %%
list1 = [10,1,10,2,10]

# %%
list1.remove(10)  ## Only first 10 removed, and so on if enter 10

# %%
list1
# Out:
# [1, 10, 2, 10]

# %%
## Remove all 10 in list1

# %%
while(10 in list1):  ## this loop as long as 10 in list1
    list1.remove(10)

# %%
list1
# Out:
# [1, 2]

# %%
for 10 in list1:  ## Not working while is working
    list1.remove(10)
# Out:
#   File "<ipython-input-102-3445c7818add>", line 1
#     for 10 in list1:
#         ^
# SyntaxError: cannot assign to literal

# %%
list1
# Out:
# [10, 1, 10, 2, 10]

# %%
## delete remove based on index

# %%
del list1[0]

# %%
list1
# Out:
# [1, 10, 2, 10]

# %%
## Checking all function in string

# %%
dir(str1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# ### A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
# ##### https://www.w3schools.com/python/python_for_loops.asp

# %%
dir(str)  ## checking all functions in string
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# # Dictionary

# %%
## eg if we appear in exam and score in various subject

# %%
"""   
physics = 45,
chem = 46
math =67

"""
# Out:
# '   \nphysics = 45\nchemistry = 45\nmath =67\n\n'

# %%
dict1 = {
    "physics":45,   ## This is called key value pair .. eg physics key and 45 is value
    "chem":46,
    "math":67
        
}

# %%
type(dict1)  ## is dictionary datatype
# Out:
# dict

# %%
dict1['math'] ## Will give us value
# Out:
# 67

# %%
## Now we want to change marks

# %%
dict1['math'] = 75

# %%
dict1  ## Dictionary is also modified.
# Out:
# {'physics': 45, 'chem': 46, 'math': 75}

# %%
## Dictionary is also modified.
## Key is always unique in dictionary

# %%
dict1.keys()  ## for knowing dictionary
# Out:
# dict_keys(['physics', 'chem', 'math'])

# %%
dict1.values() # for knowing values
# Out:
# dict_values([45, 46, 75])

# %%
dict1.items()  ## ## for knowing both
# Out:
# dict_items([('physics', 45), ('chem', 46), ('math', 75)])

# %%
## ('physics', 45) is called tuple
## Inside dictionary there is list [], along with three tupple

# %%
dict1['Hindi'] = 59  ## Adding new item to dictionary

# %%
dict1
# Out:
# {'physics': 45, 'chem': 46, 'math': 75, 'Hindi': 59}

# %%
dict1['Hindi'] = [59, 56]  ## Inserting two values for key by creating list

# %%
dict1
# Out:
# {'physics': 45, 'chem': 46, 'math': 75, 'Hindi': [59, 56]}
